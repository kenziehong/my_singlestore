# %%
# %%sql
#
# CREATE DATABASE IF NOT EXISTS timeseries_db;
#
# USE timeseries_db;
#
# CREATE TABLE IF NOT EXISTS tick (
#         symbol VARCHAR(10),
#         ts     DATETIME SERIES TIMESTAMP,
#         open   NUMERIC(18, 2),
#         high   NUMERIC(18, 2),
#         low    NUMERIC(18, 2),
#         price  NUMERIC(18, 2),
#         volume INT,
#         KEY(ts)
# );
#
# CREATE TABLE IF NOT EXISTS stock_sentiment (
#         headline  VARCHAR(250),
#         positive  FLOAT,
#         negative  FLOAT,
#         neutral   FLOAT,
#         url       TEXT,
#         publisher VARCHAR(30),
#         ts        DATETIME,
#         symbol    VARCHAR(10)
# );
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
#
# CREATE PIPELINE tick
# AS LOAD DATA KAFKA 'public-kafka.memcompute.com:9092/stockticker'
# BATCH_INTERVAL 2500
# INTO TABLE tick
# FIELDS TERMINATED BY ','
# (symbol,ts,open,high,low,price,volume);
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# ALTER PIPELINE tick SET OFFSETS EARLIEST;
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# TEST PIPELINE tick LIMIT 1;
# Out:
# +--------+---------------------+--------+--------+--------+--------+--------+
# | symbol |          ts         |  open  |  high  |  low   | price  | volume |
# +--------+---------------------+--------+--------+--------+--------+--------+
# |  RTN   | 2023-11-15 01:24:21 | 145.48 | 145.52 | 145.36 | 145.36 |  4111  |
# +--------+---------------------+--------+--------+--------+--------+--------+

# %%
# %%sql
# START PIPELINE tick;
# Out:
# ++
# ||
# ++
# ++

# %%
# !git clone https://github.com/VeryFatBoy/openai-whisper.git
# Out:
# Cloning into 'openai-whisper'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 36 (delta 11), reused 35 (delta 10), pack-reused 0
# Receiving objects: 100% (36/36), 41.08 KiB | 20.54 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# !ls openai-whisper/dataset/stock_sentiment.csv
# Out:
# stock_sentiment.csv

# %%
import pandas as pd

# Load csv file as pandas dataframe
data = pd.read_csv("openai-whisper/dataset/stock_sentiment.csv", sep='\t')
data
# Out:
#                                               headline  positive  negative  \
# 0    Agilent Technologies Announces Pricing of $5……...  0.110814  0.012814
# 1    Agilent (A) Gears Up for Q2 Earnings: What's i...  0.068731  0.018787
# 2    Pershing Square Capital Management, L.P. Buys ...  0.093213  0.011666
# 3    J.P. Morgan Asset Management Announces Liquida...  0.014791  0.848804
# 4    Agilent Awards Trilogy Sciences with a Golden ...  0.627051  0.011495
# ..                                                 ...       ...       ...
# 295  Tracking Dan Loeb's Third Point Portfolio - Q3...  0.028416  0.027418
# 296   Illumina's Growth Shows No Signs of Slowing Down  0.924818  0.019809
# 297  Agilent Technologies (A) Earnings Expected to ...  0.220927  0.013274
# 298  Tracking William Von Mueffling's Cantillon Cap...  0.034504  0.018756
# 299        Agilent launches new water quality analyzer  0.181413  0.009319
#
#       neutral                                                url  \
# 0    0.876372  http://www.gurufocus.com/news/1153187/agilent-...
# 1    0.912482  http://www.zacks.com/stock/news/931205/agilent...
# 2    0.895121  http://www.gurufocus.com/news/1138704/pershing...
# 3    0.136405  http://www.gurufocus.com/news/1138923/jp-morga...
# 4    0.361453  http://www.gurufocus.com/news/1134012/agilent-...
# ..        ...                                                ...
# 295  0.944166  https://seekingalpha.com/article/4221202-track...
# 296  0.055373  http://www.gurufocus.com/news/768939/illuminas...
# 297  0.765799  http://www.zacks.com/stock/news/337026/agilent...
# 298  0.946739  https://seekingalpha.com/article/4221012-track...
# 299  0.809268  https://seekingalpha.com/news/3404892-agilent-...
#
#          publisher                   ts symbol
# 0        GuruFocus  2020-06-01 00:00:00      A
# 1            Zacks  2020-05-18 00:00:00      A
# 2        GuruFocus  2020-05-15 00:00:00      A
# 3        GuruFocus  2020-05-15 00:00:00      A
# 4        GuruFocus  2020-05-12 00:00:00      A
# ..             ...                  ...    ...
# 295  Seeking Alpha  2018-11-12 00:00:00      A
# 296      GuruFocus  2018-11-12 00:00:00      A
# 297          Zacks  2018-11-12 00:00:00      A
# 298  Seeking Alpha  2018-11-11 00:00:00      A
# 299  Seeking Alpha  2018-11-02 00:00:00      A
#
# [300 rows x 8 columns]

# %%
from sqlalchemy import *
    
# create sqlalchemy engine
db_connection = create_engine(connection_url)

# Save dataframe to database, assign the tablename
data.to_sql('stock_sentiment', con = db_connection, if_exists = 'append', index=False, chunksize = 1000)
# Out:
# 300
